# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
df=pd.read_csv("Cereals.csv")
df
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 0           100NaturalBran   Q    C       120        3    5      15    2.0
# 1                 All-Bran   K    C        70        4    1     260    9.0
# 2   All-BranwithExtraFiber   K    C        50        4    0     140   14.0
# 3            AlmondDelight   R    C       110        2    2     200    1.0
# 4    AppleCinnamonCheerios   G    C       110        2    2     180    1.5
# ..                     ...  ..  ...       ...      ...  ...     ...    ...
# 71                 Triples   G    C       110        2    1     250    0.0
# 72                    Trix   G    C       110        1    1     140    0.0
# 73               WheatChex   R    C       100        3    1     230    3.0
# 74                Wheaties   G    C       100        3    1     200    3.0
# 75       WheatiesHoneyGold   G    C       110        2    1     200    1.0
#
#    carbo sugars potass  vitamins  shelf  weight  cups     rating
# ...

# %%
df[['protein','fat','sodium','fiber','carbo','sugars','potass','vitamins']].describe()
# Out:
#          protein        fat      sodium      fiber      carbo     sugars  \
# count  76.000000  76.000000   76.000000  76.000000  76.000000  76.000000
# mean    2.526316   1.013158  160.065789   2.048684  14.933333   7.040000
# std     1.089020   1.013159   84.318813   2.219038   3.737498   4.377031
# min     1.000000   0.000000    0.000000   0.000000   7.000000   0.000000
# 25%     2.000000   0.000000  132.500000   0.750000  12.000000   3.000000
# 50%     2.500000   1.000000  180.000000   1.750000  14.966667   7.000000
# 75%     3.000000   2.000000  212.500000   3.000000  17.000000  11.000000
# max     6.000000   5.000000  320.000000  14.000000  23.000000  15.000000
#
#            potass    vitamins
# count   76.000000   76.000000
# mean    96.216216   28.289474
# std     66.687384   22.487813
# min     15.000000    0.000000
# 25%     43.750000   25.000000
# 50%     90.000000   25.000000
# 75%    120.000000   25.000000
# max    330.000000  100.000000

# %%
df.mask(df=='?',np.nan)
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 0           100NaturalBran   Q    C       120        3    5      15    2.0
# 1                 All-Bran   K    C        70        4    1     260    9.0
# 2   All-BranwithExtraFiber   K    C        50        4    0     140   14.0
# 3            AlmondDelight   R    C       110        2    2     200    1.0
# 4    AppleCinnamonCheerios   G    C       110        2    2     180    1.5
# ..                     ...  ..  ...       ...      ...  ...     ...    ...
# 71                 Triples   G    C       110        2    1     250    0.0
# 72                    Trix   G    C       110        1    1     140    0.0
# 73               WheatChex   R    C       100        3    1     230    3.0
# 74                Wheaties   G    C       100        3    1     200    3.0
# 75       WheatiesHoneyGold   G    C       110        2    1     200    1.0
#
#    carbo sugars potass  vitamins  shelf  weight  cups     rating
# ...

# %%
num=pd.to_numeric(df['carbo'],errors='coerce')
df['carbo']=num.fillna(num.mean())

# %%
num=pd.to_numeric(df['sugars'],errors='coerce')
df['sugars']=num.fillna(num.mean())

# %%
num=pd.to_numeric(df['potass'],errors='coerce')
df['potass']=num.fillna(num.mean())

# %%
df
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 0           100NaturalBran   Q    C       120        3    5      15    2.0
# 1                 All-Bran   K    C        70        4    1     260    9.0
# 2   All-BranwithExtraFiber   K    C        50        4    0     140   14.0
# 3            AlmondDelight   R    C       110        2    2     200    1.0
# 4    AppleCinnamonCheerios   G    C       110        2    2     180    1.5
# ..                     ...  ..  ...       ...      ...  ...     ...    ...
# 71                 Triples   G    C       110        2    1     250    0.0
# 72                    Trix   G    C       110        1    1     140    0.0
# 73               WheatChex   R    C       100        3    1     230    3.0
# 74                Wheaties   G    C       100        3    1     200    3.0
# 75       WheatiesHoneyGold   G    C       110        2    1     200    1.0
#
# ...

# %%
nut=df[['protein','fat','sodium','fiber','carbo','sugars','potass','vitamins']]
nut.describe()
# Out:
#          protein        fat      sodium      fiber      carbo     sugars  \
# count  76.000000  76.000000   76.000000  76.000000  76.000000  76.000000
# mean    2.526316   1.013158  160.065789   2.048684  14.933333   7.040000
# std     1.089020   1.013159   84.318813   2.219038   3.737498   4.377031
# min     1.000000   0.000000    0.000000   0.000000   7.000000   0.000000
# 25%     2.000000   0.000000  132.500000   0.750000  12.000000   3.000000
# 50%     2.500000   1.000000  180.000000   1.750000  14.966667   7.000000
# 75%     3.000000   2.000000  212.500000   3.000000  17.000000  11.000000
# max     6.000000   5.000000  320.000000  14.000000  23.000000  15.000000
#
#            potass    vitamins
# count   76.000000   76.000000
# mean    96.216216   28.289474
# std     66.687384   22.487813
# min     15.000000    0.000000
# 25%     43.750000   25.000000
# 50%     90.000000   25.000000
# 75%    120.000000   25.000000
# max    330.000000  100.000000

# %%
for col in nut:
    Q1=np.quantile(df[col],0.25)
    Q3=np.quantile(df[col],0.75)
    IQR=Q3-Q1
    lower_bound= Q1-(1.5*IQR)
    upper_bound= Q3+(1.5*IQR)
    Q2= df[col].median()
    df[col]= np.where(df[col]>upper_bound,Q2,df[col])
    df[col]= np.where(df[col]<lower_bound,Q2,df[col])

# %%
df
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 0           100NaturalBran   Q    C       120      3.0  5.0    15.0   2.00
# 1                 All-Bran   K    C        70      4.0  1.0   260.0   1.75
# 2   All-BranwithExtraFiber   K    C        50      4.0  0.0   140.0   1.75
# 3            AlmondDelight   R    C       110      2.0  2.0   200.0   1.00
# 4    AppleCinnamonCheerios   G    C       110      2.0  2.0   180.0   1.50
# ..                     ...  ..  ...       ...      ...  ...     ...    ...
# 71                 Triples   G    C       110      2.0  1.0   250.0   0.00
# 72                    Trix   G    C       110      1.0  1.0   140.0   0.00
# 73               WheatChex   R    C       100      3.0  1.0   230.0   3.00
# 74                Wheaties   G    C       100      3.0  1.0   200.0   3.00
# 75       WheatiesHoneyGold   G    C       110      2.0  1.0   200.0   1.00
#
# ...

# %%
df[['protein','fat','sodium','fiber','carbo','sugars','potass','vitamins']].describe()
# Out:
#          protein        fat      sodium      fiber      carbo     sugars  \
# count  76.000000  76.000000   76.000000  76.000000  76.000000  76.000000
# mean    2.401316   1.013158  181.381579   1.792105  14.933333   7.040000
# std     0.875670   1.013159   60.186370   1.520220   3.737498   4.377031
# min     1.000000   0.000000   15.000000   0.000000   7.000000   0.000000
# 25%     2.000000   0.000000  147.500000   0.750000  12.000000   3.000000
# 50%     2.250000   1.000000  180.000000   1.625000  14.966667   7.000000
# 75%     3.000000   2.000000  212.500000   3.000000  17.000000  11.000000
# max     4.000000   5.000000  320.000000   6.000000  23.000000  15.000000
#
#            potass  vitamins
# count   76.000000      76.0
# mean    85.821479      25.0
# std     48.062504       0.0
# min     15.000000      25.0
# 25%     43.750000      25.0
# 50%     90.000000      25.0
# 75%    110.000000      25.0
# max    230.000000      25.0

# %%
pd.crosstab(df['type'],df['mfr'])
# Out:
# mfr   A   G   K  N  P  Q  R
# type
# C     0  22  23  4  9  7  8
# H     1   0   0  1  0  1  0

# %%
df.loc[df['rating']==df['rating'].max()]
# Out:
#                      name mfr type  calories  protein  fat  sodium  fiber  \
# 2  All-BranwithExtraFiber   K    C        50      4.0  0.0   140.0   1.75
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 2    8.0     0.0    90.0      25.0      3     1.0   0.5  93.704912

# %%
df.loc[df['rating']==df['rating'].min()]
# Out:
#          name mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 9  CapnCrunch   Q    C       120      1.0  2.0   220.0    0.0   12.0    12.0
#
#    potass  vitamins  shelf  weight  cups     rating
# 9    35.0      25.0      2     1.0  0.75  18.042851

# %%
sns.boxplot(data=df,x='type',y='rating')
# Out:
# <AxesSubplot:xlabel='type', ylabel='rating'>

# %%
df[['sugars','calories','carbo','fat']].corr()
# Out:
#             sugars  calories     carbo       fat
# sugars    1.000000  0.574182 -0.501086  0.300664
# calories  0.574182  1.000000  0.207331  0.510630
# carbo    -0.501086  0.207331  1.000000 -0.311619
# fat       0.300664  0.510630 -0.311619  1.000000

# %%
sns.pairplot(df,kind='reg',vars=['sugars','calories','carbo','fat'])

# %%
df['mfr'].loc[df['calories']==df['calories'].max()]
# Out:
# 45    K
# Name: mfr, dtype: object

# %%
df['calories'].corr(df['rating'])
# Out:
# -0.6743360496799723

# %%
sns.pairplot(df,kind='reg',vars=['calories','rating'])

# %%
df['shelf'].corr(df['calories'])
# Out:
# 0.1250085852775354

# %%
sns.pairplot(df,kind='reg',vars=['shelf','calories'])

# %%
sns.boxplot(data=df,x='mfr',y='rating')
# Out:
# <AxesSubplot:xlabel='mfr', ylabel='rating'>

# %%
df.loc[df['rating']>=60]
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 2   All-BranwithExtraFiber   K    C        50      4.0  0.0   140.0   1.75
# 19       CreamofWheatQuick   N    H       100      3.0  0.0    80.0   1.00
# 53              PuffedRice   Q    C        50      1.0  0.0   180.0   0.00
# 54             PuffedWheat   Q    C        50      2.0  0.0   180.0   1.00
# 62           ShreddedWheat   N    C        80      2.0  0.0   180.0   3.00
# 63      ShreddedWheatnBran   N    C        90      3.0  0.0   180.0   4.00
# 64  ShreddedWheatspoonsize   N    C        90      3.0  0.0   180.0   3.00
#
#     carbo  sugars      potass  vitamins  shelf  weight  cups     rating
# 2     8.0     0.0   90.000000      25.0      3    1.00  0.50  93.704912
# 19   21.0     0.0   96.216216      25.0      2    1.00  1.00  64.533816
# 53   13.0     0.0   15.000000      25.0      3    0.50  1.00  60.756112
# 54   10.0     0.0   50.000000      25.0      3    0.50  1.00  63.005645
# ...

# %%
gnut=df[["protein","fat","sodium","carbo","potass","vitamins","sugars","fiber"]].loc[df['rating']>60]
gnut
# Out:
#     protein  fat  sodium  carbo      potass  vitamins  sugars  fiber
# 2       4.0  0.0   140.0    8.0   90.000000      25.0     0.0   1.75
# 19      3.0  0.0    80.0   21.0   96.216216      25.0     0.0   1.00
# 53      1.0  0.0   180.0   13.0   15.000000      25.0     0.0   0.00
# 54      2.0  0.0   180.0   10.0   50.000000      25.0     0.0   1.00
# 62      2.0  0.0   180.0   16.0   95.000000      25.0     0.0   3.00
# 63      3.0  0.0   180.0   19.0  140.000000      25.0     0.0   4.00
# 64      3.0  0.0   180.0   20.0  120.000000      25.0     0.0   3.00

# %%
sns.heatmap(df[[ 'calories', 'protein', 'fat', 'sodium', 'fiber',
       'carbo', 'sugars', 'potass', 'vitamins','rating']].corr(), annot = True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>
