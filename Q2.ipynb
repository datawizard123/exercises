# %%
#Abhigyan Basak Reg-210968124

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#importing the data
df=pd.read_csv('ipldata.csv')
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
#q1

# %%
df[df.result=="tie"]
# Out:
#         id  season       city        date                        team1  \
# 33      34    2017     Rajkot  2017-04-29                Gujarat Lions
# 125    126    2009  Cape Town  2009-04-23             Rajasthan Royals
# 189    190    2010    Chennai  2010-03-21              Kings XI Punjab
# 387    388    2013  Hyderabad  2013-04-07  Royal Challengers Bangalore
# 400    401    2013  Bangalore  2013-04-16             Delhi Daredevils
# 475    476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 535    536    2015  Ahmedabad  2015-04-21             Rajasthan Royals
# 705  11146    2019      Delhi    30/03/19        Kolkata Knight Riders
# 746  11342    2019     Mumbai    02/05/19               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 33                Mumbai Indians                Gujarat Lions           bat
# 125        Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %%
df[df.result=="tie"].shape[0]
# Out:
# 9

# %%
#9 matches resulted in tie

# %%
#q2

# %%
df.winner.unique()
# Out:
# array(['Sunrisers Hyderabad', 'Rising Pune Supergiant',
#        'Kolkata Knight Riders', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Mumbai Indians',
#        'Delhi Daredevils', 'Gujarat Lions', 'Chennai Super Kings',
#        'Rajasthan Royals', 'Deccan Chargers', 'Pune Warriors',
#        'Kochi Tuskers Kerala', nan, 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
#rising pune supergiants appear twice, one has a 's' at the end

# %%
df.replace('Rising Pune Supergiant','Rising Pune Supergiants',inplace=True)
df.winner.unique()
# Out:
# array(['Sunrisers Hyderabad', 'Rising Pune Supergiants',
#        'Kolkata Knight Riders', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Mumbai Indians',
#        'Delhi Daredevils', 'Gujarat Lions', 'Chennai Super Kings',
#        'Rajasthan Royals', 'Deccan Chargers', 'Pune Warriors',
#        'Kochi Tuskers Kerala', nan, 'Delhi Capitals'], dtype=object)

# %%
#Fixed

# %%
df.season.sort_values().unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019], dtype=int64)

# %%
for i in df.season.sort_values().unique():
    print(i)
    print(df[df['season']==i].winner.value_counts().nlargest(1))
# Out:
# 2008
# Rajasthan Royals    13
# Name: winner, dtype: int64
# 2009
# Delhi Daredevils    10
# Name: winner, dtype: int64
# 2010
# Mumbai Indians    11
# Name: winner, dtype: int64
# 2011
# Chennai Super Kings    11
# Name: winner, dtype: int64
# 2012
# Kolkata Knight Riders    12
# Name: winner, dtype: int64
# 2013
# Mumbai Indians    13
# Name: winner, dtype: int64
# 2014
# Kings XI Punjab    12
# Name: winner, dtype: int64
# 2015
# Mumbai Indians    10
# Name: winner, dtype: int64
# 2016
# Sunrisers Hyderabad    11
# Name: winner, dtype: int64
# 2017
# Mumbai Indians    12
# Name: winner, dtype: int64
# 2018
# Chennai Super Kings    11
# Name: winner, dtype: int64
# 2019
# Mumbai Indians    11
# Name: winner, dtype: int64

# %%
#q3

# %%
for i in ['umpire1','umpire2','umpire3']:
    print("Umpire "+i+" max: ")
    a=[]
    print(df[i].value_counts().nlargest(5))
    a=df[i].value_counts().nlargest(1)
# Out:
# Umpire umpire1 max:
# HDPK Dharmasena    73
# Asad Rauf          51
# S Ravi             49
# AK Chaudhary       43
# Aleem Dar          38
# Name: umpire1, dtype: int64
# Umpire umpire2 max:
# C Shamshuddin    57
# S Ravi           57
# SJA Taufel       54
# RJ Tucker        38
# CK Nandan        36
# Name: umpire2, dtype: int64
# Umpire umpire3 max:
# Nitin Menon       10
# O Nandan          10
# C Shamshuddin     10
# Anil Chaudhary     9
# S Ravi             8
# Name: umpire3, dtype: int64

# %%
#q4

# %%
df.city.value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Dharamsala          9
# Indore              9
# Johannesburg        8
# Cape Town           7
# Cuttack             7
# Ranchi              7
# Abu Dhabi           7
# Port Elizabeth      7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# East London         3
# Kimberley           3
# Nagpur              3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
df.city.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
#q5

# %%
df.toss_winner.value_counts().nlargest(5)
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Name: toss_winner, dtype: int64

# %%
pd.crosstab(df['toss_winner'],df['toss_decision'])
# Out:
# toss_decision                bat  field
# toss_winner
# Chennai Super Kings           48     41
# Deccan Chargers               24     19
# Delhi Capitals                 2      8
# Delhi Daredevils              29     51
# Gujarat Lions                  1     14
# Kings XI Punjab               26     55
# Kochi Tuskers Kerala           3      5
# Kolkata Knight Riders         30     62
# Mumbai Indians                44     54
# Pune Warriors                 11      9
# Rajasthan Royals              32     48
# Rising Pune Supergiants        3     10
# Royal Challengers Bangalore   20     61
# Sunrisers Hyderabad           20     26

# %%
pd.crosstab(df['toss_winner'],df['toss_decision']).plot.bar()
plt.ylabel('Toss Decision')
plt.show()
